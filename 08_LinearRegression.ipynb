# %%
import pandas as pd
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

# %%
boston = pd.read_csv('HousingData.csv')
boston.fillna(boston.mean(), inplace=True)
x = boston.drop(columns=['MEDV']).values
y = boston['MEDV'].values
# print(x)
# print(y)

# %%
plt.scatter(x.T[4],y)
plt.show()

# %%
l_reg = linear_model.LinearRegression()
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.05)
model = l_reg.fit(x_train,y_train)
predictions = model.predict(x_test)
print('Actual data: ', y_test)
print('Predictions: ', predictions)
print('R^2 values: ',l_reg.score(x,y))
print('Coedd: ', l_reg.coef_)
print('Intercept: ', l_reg.intercept_)
# Out:
# Actual data:  [20.2 23.5 28.  17.2 19.3 43.1 22.8  9.6 20.4 18.9 16.8 12.3 20.4 18.9
#  22.2 24.1 26.7 21.5 20.6 22.8 36.4 15.2 16.1 19.2 26.4 14.1]
# Predictions:  [16.64269196 30.5090747  28.69057138 14.92602039 22.40165486 37.38520435
#  24.84368802 14.378323   21.13147596 22.57816425 20.74755952 18.81000035
#  22.96860173 21.29255512 22.19666098 20.30616036 34.00183632 25.51363093
#  12.76157396 28.30729349 32.77873355 19.77103953 18.5672477  23.71622219
#  28.96325138 17.41691453]
# R^2 values:  0.7309061161511002
# Coedd:  [-1.17320961e-01  4.33930597e-02 -3.41525620e-02  3.36858017e+00
#  -1.75375741e+01  4.01457941e+00 -1.25408798e-02 -1.59687257e+00
#   2.93666043e-01 -1.13660009e-02 -9.40339206e-01  9.73022448e-03
#  -4.67435594e-01]
# Intercept:  35.782267025796386
